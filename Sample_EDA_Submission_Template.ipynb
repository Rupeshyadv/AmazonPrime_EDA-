# %% [markdown]
# # **Project Name**    - Amazon Prime TV Shows and Movies - EDA

# %% [markdown]
# ##### **Project Type**    - EDA/Regression/Classification/Unsupervised
# ##### **Contribution**    - Individual/Team
# ##### **Team Member 1 -**
# ##### **Team Member 2 -**
# ##### **Team Member 3 -**
# ##### **Team Member 4 -**

# %% [markdown]
# # **Project Summary -**

# %% [markdown]
# Write the summary here within 500-600 words.

# %% [markdown]
# # **GitHub Link -**

# %% [markdown]
# https://github.com/Rupeshyadv/AmazonPrime_EDA-

# %% [markdown]
# # **Problem Statement**

# %% [markdown]
# **Write Problem Statement Here.**

# %% [markdown]
# #### **Define Your Business Objective?**

# %% [markdown]
# Answer Here.

# %% [markdown]
# # **General Guidelines** : -

# %% [markdown]
# 1.   Well-structured, formatted, and commented code is required.
# 2.   Exception Handling, Production Grade Code & Deployment Ready Code will be a plus. Those students will be awarded some additional credits.
#
#      The additional credits will have advantages over other students during Star Student selection.
#
#              [ Note: - Deployment Ready Code is defined as, the whole .ipynb notebook should be executable in one go
#                        without a single error logged. ]
#
# 3.   Each and every logic should have proper comments.
# 4. You may add as many number of charts you want. Make Sure for each and every chart the following format should be answered.
#
#
# ```
# # Chart visualization code
# ```
#
#
# *   Why did you pick the specific chart?
# *   What is/are the insight(s) found from the chart?
# * Will the gained insights help creating a positive business impact?
# Are there any insights that lead to negative growth? Justify with specific reason.
#
# 5. You have to create at least 20 logical & meaningful charts having important insights.
#
#
# [ Hints : - Do the Vizualization in  a structured way while following "UBM" Rule.
#
# U - Univariate Analysis,
#
# B - Bivariate Analysis (Numerical - Categorical, Numerical - Numerical, Categorical - Categorical)
#
# M - Multivariate Analysis
#  ]

# %% [markdown]
# # ***Let's Begin !***

# %% [markdown]
# ## ***1. Know Your Data***

# %% [markdown]
# ### Import Libraries

# %%
# Import Libraries
import numpy as np 
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %% [markdown]
# ### Dataset Loading

# %%
# Load Dataset
# read the raw data from a zipped CSV file
credits_df = pd.read_csv('./data/raw_data/credits.csv.zip')
titles_df = pd.read_csv('./data/raw_data/titles.csv.zip')

# %% [markdown]
# ### Dataset First View

# %%
# Dataset First Look
# display the first and last 5 rows of the credits dataset
print("\nCredits Dataset First and Last 5 Rows:")
display(credits_df.head())
display(credits_df.tail())
# display the first and last 5 rows of the titles dataset
print("\nTitles Dataset First and Last 5 Rows:")
display(titles_df.head())   
display(titles_df.tail())
# Out:
# Credits Dataset First and Last 5 Rows:
#    person_id       id           name      character   role
# 0      59401  ts20945     Joe Besser            Joe  ACTOR
# 1      31460  ts20945     Moe Howard            Moe  ACTOR
# 2      31461  ts20945     Larry Fine          Larry  ACTOR
# 3      21174  tm19248  Buster Keaton    Johnny Gray  ACTOR
# 4      28713  tm19248    Marion Mack  Annabelle Lee  ACTOR
#         person_id         id           name      character      role
# 124230    1938589  tm1054116  Sangam Shukla         Madhav     ACTOR
# 124231    1938565  tm1054116   Vijay Thakur  Sanjay Thakur     ACTOR
# 124232     728899  tm1054116  Vanya Wellens        Budhiya     ACTOR
# 124233    1938620  tm1054116   Vishwa Bhanu          Gissu     ACTOR
# 124234    1938620  tm1054116   Vishwa Bhanu            NaN  DIRECTOR
# Titles Dataset First and Last 5 Rows:
#         id                        title   type  \
# 0  ts20945            The Three Stooges   SHOW
# ...

# %% [markdown]
# ### Dataset Rows & Columns count

# %%
# Dataset Rows & Columns count
# check the number of rows and columns in credits dataset
print("Credits Dataset Shape:", credits_df.shape) # 124235 rows and 5 columns
# check the number of rows and columns in titles dataset
print("Titles Dataset Shape:", titles_df.shape) # 9871 rows and 15 columns
# Out:
# Credits Dataset Shape: (124235, 5)
# Titles Dataset Shape: (9871, 15)

# %% [markdown]
# ### Dataset Information

# %%
# Dataset Info
# check the info of credits dataset
print("Credits Dataset Info: \n")
print(credits_df.info())
print("\n")
# check the info of titles dataset
print("Titles Dataset Info: \n")
print("Titles Dataset Info: ", titles_df.info())
# Out:
# Credits Dataset Info:
#
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 124235 entries, 0 to 124234
# Data columns (total 5 columns):
#  #   Column     Non-Null Count   Dtype
# ---  ------     --------------   -----
#  0   person_id  124235 non-null  int64
#  1   id         124235 non-null  object
#  2   name       124235 non-null  object
#  3   character  107948 non-null  object
#  4   role       124235 non-null  object
# dtypes: int64(1), object(4)
# memory usage: 4.7+ MB
# None
#
#
# Titles Dataset Info:
#
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 9871 entries, 0 to 9870
# Data columns (total 15 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   id                    9871 non-null   object
#  1   title                 9871 non-null   object
#  2   type                  9871 non-null   object
#  3   description           9752 non-null   object
#  4   release_year          9871 non-null   int64
# ...

# %% [markdown]
# #### Duplicate Values

# %%
# Dataset Duplicate Value Count
# check for duplicate rows in credits dataset
print("Credits Dataset Duplicate Rows:", credits_df.duplicated().sum()) # 56 duplicate
# check for duplicate rows in titles dataset
print("Titles Dataset Duplicate Rows:", titles_df.duplicated().sum()) # 3 duplicate
# Out:
# Credits Dataset Duplicate Rows: 56
# Titles Dataset Duplicate Rows: 3

# %% [markdown]
# #### Missing Values/Null Values

# %%
# Missing Values/Null Values Count
# check for missing values in credits dataset
print("\nCredits Dataset Missing Values:\n", credits_df.isnull().sum())
# check for missing values in titles dataset
print("\nTitles Dataset Missing Values:\n", titles_df.isnull().sum())
# Out:
# Credits Dataset Missing Values:
#  person_id        0
# id               0
# name             0
# character    16287
# role             0
# dtype: int64
#
# Titles Dataset Missing Values:
#  id                         0
# title                      0
# type                       0
# description              119
# release_year               0
# age_certification       6487
# runtime                    0
# genres                     0
# production_countries       0
# seasons                 8514
# imdb_id                  667
# imdb_score              1021
# imdb_votes              1031
# tmdb_popularity          547
# tmdb_score              2082
# dtype: int64

# %%
# Visualizing the missing values
# visualize missing values in credits dataset - bar plot
missing_credits = credits_df.isnull().sum()

plt.figure(figsize=(8,6))
missing_credits.plot(kind='bar')
plt.title("Missing Values per Column - CREDITS Dataset")
plt.xlabel("Columns")
plt.ylabel("Number of Missing Values")
plt.show()

# visualize missing values in credits dataset - bar plot
missing_titles = titles_df.isnull().sum()

plt.figure(figsize=(8,6))
missing_titles.plot(kind='bar')
plt.title("Missing Values per Column - TITLES Dataset")
plt.xlabel("Columns")
plt.ylabel("Number of Missing Values")
plt.show()

# visualize combined missing values using heatmap
combined_missing = pd.DataFrame({
    "missing_credits": credits_df.isnull().sum(),
    "missing_titles": titles_df.isnull().sum()
})

plt.figure(figsize=(10,8))
sns.heatmap(combined_missing, annot=True, fmt="g", cmap="viridis")
plt.title("Missing Value Comparison: Titles vs Credits")
plt.ylabel("Columns")
plt.xlabel("Dataset")
plt.show()

# %% [markdown]
# ### What did you know about your dataset?

# %% [markdown]
# ## **1. Structure of the Datasets**
#
# ### **🔹 credits.csv**
#
# Contains information about cast and crew for each title.
#
# **Key Columns:** - `person_id` - `id` - `name` - `character` - `role`
#
# ------------------------------------------------------------------------
#
# ### **🔹 titles.csv**
#
# Contains metadata about each movie/TV show available on Amazon Prime.
#
# **Key Columns:** - `id` - `title` - `type` - `description` -
# `release_year` - `age_certification` - `runtime` - `genres` -
# `production_countries` - `seasons` - `imdb_id` - `imdb_score` -
# `imdb_votes` - `tmdb_popularity` - `tmdb_score`
#
# ------------------------------------------------------------------------
#
# ## **2. Data Quality Overview**
#
# ### **🟠 Missing & Null Values**
#
# ### credits.csv — Missing Values
#
# | Column    | Missing Values | Percentage |
# |-----------|----------------|------------|
# | character | 16,287         | 13.02%     |
#
# **Duplicates:**
# - 56 duplicate rows
#
# ------------------------------------------------------------------------
#
# ### titles.csv — Missing Values
#
# | Column              | Missing Values | Percentage |
# |---------------------|----------------|------------|
# | description         | 119            | 1.2%       |
# | age_certification   | 6,487          | 65.7%      |
# | seasons             | 8,514          | 86.3%      |
# | imdb_id             | 667            | 6.8%       |
# | imdb_score          | 1,021          | 10.3%      |
# | imdb_votes          | 1,031          | 10.4%      |
# | tmdb_popularity     | 547            | 5.6%       |
# | tmdb_score          | 2,082          | 21%        |
#
# **Duplicates:**
# - 3 duplicate rows
#
# ------------------------------------------------------------------------
#
# ## **3. Key Insights Identified**
#
# -   The credits dataset is mostly clean except for missing `character`
#     entries.
# -   The titles dataset has significant missing data in
#     `age_certification`, `seasons`, and `tmdb_score`.
# -   Missing values affect analysis of ratings and content
#     classification.
# -   A few duplicate rows exist and should be removed before modeling or
#     deeper analysis.

# %% [markdown]
# ## ***2. Understanding Your Variables***

# %%
# Dataset Columns
# credits dataset columns
print("Credits Dataset Columns:\n", credits_df.columns.tolist()) # 5 columns
# titles dataset columns
print("\nTitles Dataset Columns:\n", titles_df.columns.tolist()) # 15 columns
# Out:
# Credits Dataset Columns:
#  ['person_id', 'id', 'name', 'character', 'role']
#
# Titles Dataset Columns:
#  ['id', 'title', 'type', 'description', 'release_year', 'age_certification', 'runtime', 'genres', 'production_countries', 'seasons', 'imdb_id', 'imdb_score', 'imdb_votes', 'tmdb_popularity', 'tmdb_score']

# %%
# Dataset Describe
# credits dataset descriptive statistics
print("\nCredits Dataset Descriptive Statistics:")
display(credits_df.describe(include='all'))
# titles dataset descriptive statistics
print("\nTitles Dataset Descriptive Statistics:")
display(titles_df.describe(include='all'))
# Out:
# Credits Dataset Descriptive Statistics:
#            person_id        id                  name character    role
# count   1.242350e+05    124235                124235    107948  124235
# unique           NaN      8861                 79758     71097       2
# top              NaN  tm458582  George 'Gabby' Hayes   Himself   ACTOR
# freq             NaN       137                    49      1540  115846
# mean    4.064737e+05       NaN                   NaN       NaN     NaN
# std     5.616296e+05       NaN                   NaN       NaN     NaN
# min     1.000000e+00       NaN                   NaN       NaN     NaN
# 25%     3.899200e+04       NaN                   NaN       NaN     NaN
# 50%     1.339490e+05       NaN                   NaN       NaN     NaN
# 75%     5.712560e+05       NaN                   NaN       NaN     NaN
# max     2.371153e+06       NaN                   NaN       NaN     NaN
# Titles Dataset Descriptive Statistics:
# ...

# %% [markdown]
# ### Variables Description

# %% [markdown]
# ### credits.csv
#
# | Column     | Description |
# |------------|-------------|
# | person_id  | Unique identifier for a person appearing in the title (actor, director, etc.). |
# | id         | The title ID that links each person to a movie/TV show in titles.csv. |
# | name       | Name of the person. |
# | character  | Name of the character portrayed (for actors). Directors/writers have null here. |
# | role       | Role of the person in the production (e.g., actor, director, writer). |
#
# ---------------------------------------------------------------------------------------------------
#
# ### titles.csv
#
# | Column                | Description |
# |-----------------------|-------------|
# | id                    | Unique identifier for each title across the dataset. |
# | title                 | Name of the movie or TV Show. |
# | type                  | Indicates whether the content is a movie or tv_show. |
# | description           | Short summary of the title. |
# | release_year          | Year in which the title was released. |
# | age_certification     | The age rating assigned to the title (e.g., PG, R, TV-14). |
# | runtime               | Duration of the movie or each TV episode (in minutes). |
# | genres                | Comma-separated list of genres (e.g., Drama, Action). |
# | production_countries  | Countries involved in producing the title. |
# | seasons               | Number of seasons (TV shows only). |
# | imdb_id               | Unique identifier for the title on IMDb. |
# | imdb_score            | IMDb rating (0–10). |
# | imdb_votes            | Number of votes on IMDb. |
# | tmdb_popularity       | Popularity score from TMDB. |
# | tmdb_score            | User rating score on TMDB. |

# %% [markdown]
# ### Check Unique Values for each variable.

# %%
# Check Unique Values for each variable.
# credits dataset unique values per column
print("\nCredits Dataset Unique Values per Column:")
for column in credits_df.columns:
    unique_values = credits_df[column].nunique()
    print(f"'{column}': {unique_values} unique values")
# titles dataset unique values per column
print("\nTitles Dataset Unique Values per Column:")
for column in titles_df.columns:
    unique_values = titles_df[column].nunique()
    print(f"'{column}': {unique_values} unique values")
# Out:
# Credits Dataset Unique Values per Column:
# 'person_id': 80508 unique values
# 'id': 8861 unique values
# 'name': 79758 unique values
# 'character': 71097 unique values
# 'role': 2 unique values
#
# Titles Dataset Unique Values per Column:
# 'id': 9868 unique values
# 'title': 9737 unique values
# 'type': 2 unique values
# 'description': 9734 unique values
# 'release_year': 110 unique values
# 'age_certification': 11 unique values
# 'runtime': 207 unique values
# 'genres': 2028 unique values
# 'production_countries': 497 unique values
# 'seasons': 32 unique values
# 'imdb_id': 9201 unique values
# 'imdb_score': 86 unique values
# 'imdb_votes': 3650 unique values
# 'tmdb_popularity': 5325 unique values
# 'tmdb_score': 89 unique values

# %% [markdown]
# ## 3. ***Data Wrangling***

# %% [markdown]
# ### Data Wrangling Code

# %%
# ===============================
# REMOVE DUPLICATES
# ===============================

credits_df_clean = credits_df.drop_duplicates().copy()
titles_df_clean = titles_df.drop_duplicates().copy()

# ===============================
# HANDLE MISSING VALUES (CREDITS)
# ===============================

# We DO NOT impute 'character' because:
# - Missing means the person is NOT an actor (director/writer)
# - Imputation would add wrong information
# → We leave it as is.


# ===============================
# HANDLE MISSING VALUES (TITLES)
# ===============================

# Impute description with a neutral text
titles_df_clean["description"] = titles_df_clean['description'].fillna("No Description Available")

# Impute age_certification with 'Not Rated'
titles_df_clean["age_certification"] = titles_df_clean['age_certification'].fillna("Not Rated")

# Seasons → Movies have season = 0 (correct representation)
titles_df_clean.loc[titles_df_clean['type'] == "MOVIE", "seasons"] = \
    titles_df_clean.loc[titles_df_clean['type'] == "MOVIE", "seasons"].fillna(0)

# NOTE:
# We are intentionally NOT imputing:
# - imdb_id
# - imdb_score
# - imdb_votes
# - tmdb_score
# - tmdb_popularity
# because missing values have meaning in ratings/IDs.


# ===============================
# SHOW FINAL INFO
# ===============================

print("\nCredits Dataset (Cleaned):")
credits_df_clean.info()

print("\nTitles Dataset (Cleaned):")
titles_df_clean.info()

# ===============================
# MERGE DATASETS FOR FURTHER ANALYSIS/VISUALIZATION
# ===============================

# Merge credits and titles datasets on 'id', which is common in both datasets
merged_df = pd.merge(titles_df_clean, credits_df_clean, on='id', how='left')
print("\nMerged Dataset Info:")
merged_df.info()
display(merged_df.head())
display(merged_df.tail())
# Out:
# Credits Dataset (Cleaned):
# <class 'pandas.core.frame.DataFrame'>
# Index: 124179 entries, 0 to 124234
# Data columns (total 5 columns):
#  #   Column     Non-Null Count   Dtype
# ---  ------     --------------   -----
#  0   person_id  124179 non-null  int64
#  1   id         124179 non-null  object
#  2   name       124179 non-null  object
#  3   character  107902 non-null  object
#  4   role       124179 non-null  object
# dtypes: int64(1), object(4)
# memory usage: 5.7+ MB
#
# Titles Dataset (Cleaned):
# <class 'pandas.core.frame.DataFrame'>
# Index: 9868 entries, 0 to 9870
# Data columns (total 15 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   id                    9868 non-null   object
#  1   title                 9868 non-null   object
#  2   type                  9868 non-null   object
#  3   description           9868 non-null   object
#  4   release_year          9868 non-null   int64
# ...

# %% [markdown]
# ### What all manipulations have you done and insights you found?

# %% [markdown]
# Answer Here.

# %% [markdown]
# ## ***4. Data Vizualization, Storytelling & Experimenting with charts : Understand the relationships between variables***

# %% [markdown]
# #### Chart - 1

# %%
# Chart - 1 visualization code

# %% [markdown]
# ##### 1. Why did you pick the specific chart?

# %% [markdown]
# Answer Here.

# %% [markdown]
# ##### 2. What is/are the insight(s) found from the chart?

# %% [markdown]
# Answer Here

# %% [markdown]
# ##### 3. Will the gained insights help creating a positive business impact?
# Are there any insights that lead to negative growth? Justify with specific reason.

# %% [markdown]
# Answer Here

# %% [markdown]
# #### Chart - 2

# %%
# Chart - 2 visualization code

# %% [markdown]
# ##### 1. Why did you pick the specific chart?

# %% [markdown]
# Answer Here.

# %% [markdown]
# ##### 2. What is/are the insight(s) found from the chart?

# %% [markdown]
# Answer Here

# %% [markdown]
# ##### 3. Will the gained insights help creating a positive business impact?
# Are there any insights that lead to negative growth? Justify with specific reason.

# %% [markdown]
# Answer Here

# %% [markdown]
# #### Chart - 3

# %%
# Chart - 3 visualization code

# %% [markdown]
# ##### 1. Why did you pick the specific chart?

# %% [markdown]
# Answer Here.

# %% [markdown]
# ##### 2. What is/are the insight(s) found from the chart?

# %% [markdown]
# Answer Here

# %% [markdown]
# ##### 3. Will the gained insights help creating a positive business impact?
# Are there any insights that lead to negative growth? Justify with specific reason.

# %% [markdown]
# Answer Here

# %% [markdown]
# #### Chart - 4

# %%
# Chart - 4 visualization code

# %% [markdown]
# ##### 1. Why did you pick the specific chart?

# %% [markdown]
# Answer Here.

# %% [markdown]
# ##### 2. What is/are the insight(s) found from the chart?

# %% [markdown]
# Answer Here

# %% [markdown]
# ##### 3. Will the gained insights help creating a positive business impact?
# Are there any insights that lead to negative growth? Justify with specific reason.

# %% [markdown]
# Answer Here

# %% [markdown]
# #### Chart - 5

# %%
# Chart - 5 visualization code

# %% [markdown]
# ##### 1. Why did you pick the specific chart?

# %% [markdown]
# Answer Here.

# %% [markdown]
# ##### 2. What is/are the insight(s) found from the chart?

# %% [markdown]
# Answer Here

# %% [markdown]
# ##### 3. Will the gained insights help creating a positive business impact?
# Are there any insights that lead to negative growth? Justify with specific reason.

# %% [markdown]
# Answer Here

# %% [markdown]
# #### Chart - 6

# %%
# Chart - 6 visualization code

# %% [markdown]
# ##### 1. Why did you pick the specific chart?

# %% [markdown]
# Answer Here.

# %% [markdown]
# ##### 2. What is/are the insight(s) found from the chart?

# %% [markdown]
# Answer Here

# %% [markdown]
# ##### 3. Will the gained insights help creating a positive business impact?
# Are there any insights that lead to negative growth? Justify with specific reason.

# %% [markdown]
# Answer Here

# %% [markdown]
# #### Chart - 7

# %%
# Chart - 7 visualization code

# %% [markdown]
# ##### 1. Why did you pick the specific chart?

# %% [markdown]
# Answer Here.

# %% [markdown]
# ##### 2. What is/are the insight(s) found from the chart?

# %% [markdown]
# Answer Here

# %% [markdown]
# ##### 3. Will the gained insights help creating a positive business impact?
# Are there any insights that lead to negative growth? Justify with specific reason.

# %% [markdown]
# Answer Here

# %% [markdown]
# #### Chart - 8

# %%
# Chart - 8 visualization code

# %% [markdown]
# ##### 1. Why did you pick the specific chart?

# %% [markdown]
# Answer Here.

# %% [markdown]
# ##### 2. What is/are the insight(s) found from the chart?

# %% [markdown]
# Answer Here

# %% [markdown]
# ##### 3. Will the gained insights help creating a positive business impact?
# Are there any insights that lead to negative growth? Justify with specific reason.

# %% [markdown]
# Answer Here

# %% [markdown]
# #### Chart - 9

# %%
# Chart - 9 visualization code

# %% [markdown]
# ##### 1. Why did you pick the specific chart?

# %% [markdown]
# Answer Here.

# %% [markdown]
# ##### 2. What is/are the insight(s) found from the chart?

# %% [markdown]
# Answer Here

# %% [markdown]
# ##### 3. Will the gained insights help creating a positive business impact?
# Are there any insights that lead to negative growth? Justify with specific reason.

# %% [markdown]
# Answer Here

# %% [markdown]
# #### Chart - 10

# %%
# Chart - 10 visualization code

# %% [markdown]
# ##### 1. Why did you pick the specific chart?

# %% [markdown]
# Answer Here.

# %% [markdown]
# ##### 2. What is/are the insight(s) found from the chart?

# %% [markdown]
# Answer Here

# %% [markdown]
# ##### 3. Will the gained insights help creating a positive business impact?
# Are there any insights that lead to negative growth? Justify with specific reason.

# %% [markdown]
# Answer Here

# %% [markdown]
# #### Chart - 11

# %%
# Chart - 11 visualization code

# %% [markdown]
# ##### 1. Why did you pick the specific chart?

# %% [markdown]
# Answer Here.

# %% [markdown]
# ##### 2. What is/are the insight(s) found from the chart?

# %% [markdown]
# Answer Here

# %% [markdown]
# ##### 3. Will the gained insights help creating a positive business impact?
# Are there any insights that lead to negative growth? Justify with specific reason.

# %% [markdown]
# Answer Here

# %% [markdown]
# #### Chart - 12

# %%
# Chart - 12 visualization code

# %% [markdown]
# ##### 1. Why did you pick the specific chart?

# %% [markdown]
# Answer Here.

# %% [markdown]
# ##### 2. What is/are the insight(s) found from the chart?

# %% [markdown]
# Answer Here

# %% [markdown]
# ##### 3. Will the gained insights help creating a positive business impact?
# Are there any insights that lead to negative growth? Justify with specific reason.

# %% [markdown]
# Answer Here

# %% [markdown]
# #### Chart - 13

# %%
# Chart - 13 visualization code

# %% [markdown]
# ##### 1. Why did you pick the specific chart?

# %% [markdown]
# Answer Here.

# %% [markdown]
# ##### 2. What is/are the insight(s) found from the chart?

# %% [markdown]
# Answer Here

# %% [markdown]
# ##### 3. Will the gained insights help creating a positive business impact?
# Are there any insights that lead to negative growth? Justify with specific reason.

# %% [markdown]
# Answer Here

# %% [markdown]
# #### Chart - 14 - Correlation Heatmap

# %%
# Correlation Heatmap visualization code

# %% [markdown]
# ##### 1. Why did you pick the specific chart?

# %% [markdown]
# Answer Here.

# %% [markdown]
# ##### 2. What is/are the insight(s) found from the chart?

# %% [markdown]
# Answer Here

# %% [markdown]
# #### Chart - 15 - Pair Plot

# %%
# Pair Plot visualization code

# %% [markdown]
# ##### 1. Why did you pick the specific chart?

# %% [markdown]
# Answer Here.

# %% [markdown]
# ##### 2. What is/are the insight(s) found from the chart?

# %% [markdown]
# Answer Here

# %% [markdown]
# ## **5. Solution to Business Objective**

# %% [markdown]
# #### What do you suggest the client to achieve Business Objective ?
# Explain Briefly.

# %% [markdown]
# Answer Here.

# %% [markdown]
# # **Conclusion**

# %% [markdown]
# Write the conclusion here.

# %% [markdown]
# ### ***Hurrah! You have successfully completed your EDA Capstone Project !!!***
